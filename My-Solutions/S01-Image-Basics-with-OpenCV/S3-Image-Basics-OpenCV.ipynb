# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('../../DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
#Now whe have to transfor this image, because OPENCV expects to receive the 
# order of colours: BLUE, GREEN RED. Instead MATPLOTLIB (RGB)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('../../DATA/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img, (1000,400))

# %%
plt.imshow(new_img)

# %%
w_ratio=0.5
h_ratio=0.5

# %%
new_img=cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_imgFlip= cv2.flip(fix_img,0)
plt.imshow(new_imgFlip)

# %%
#To save files or images
cv2.imwrite('totally-new.jpg', fix_img)
# Out:
# True

# %%
#white canvas space 10'x 8' in the Jupiter notebook
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
